# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./SDN Dataset/dataset_sdn.csv")

# %%
df.head()
# Out:
#       dt  switch       src       dst  pktcount  bytecount  dur   dur_nsec  \
# 0  11425       1  10.0.0.1  10.0.0.8     45304   48294064  100  716000000
# 1  11605       1  10.0.0.1  10.0.0.8    126395  134737070  280  734000000
# 2  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 3  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 4  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
#
#         tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no   tx_bytes  \
# 0  1.010000e+11      3  ...      451         0       UDP        3  143928631
# 1  2.810000e+11      2  ...      451         0       UDP        4       3842
# 2  2.010000e+11      3  ...      451         0       UDP        1       3795
# 3  2.010000e+11      3  ...      451         0       UDP        2       3688
# 4  2.010000e+11      3  ...      451         0       UDP        3       3413
#
#   rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# ...

# %%
df.describe()
# Out:
#                   dt         switch       pktcount     bytecount  \
# count  104345.000000  104345.000000  104345.000000  1.043450e+05
# mean    17927.514169       4.214260   52860.954746  3.818660e+07
# std     11977.642655       1.956327   52023.241460  4.877748e+07
# min      2488.000000       1.000000       0.000000  0.000000e+00
# 25%      7098.000000       3.000000     808.000000  7.957600e+04
# 50%     11905.000000       4.000000   42828.000000  6.471930e+06
# 75%     29952.000000       5.000000   94796.000000  7.620354e+07
# max     42935.000000      10.000000  260006.000000  1.471280e+08
#
#                  dur      dur_nsec       tot_dur          flows  \
# count  104345.000000  1.043450e+05  1.043450e+05  104345.000000
# mean      321.497398  4.613880e+08  3.218865e+11       5.654234
# std       283.518232  2.770019e+08  2.834029e+11       2.950036
# min         0.000000  0.000000e+00  0.000000e+00       2.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104345 entries, 0 to 104344
# Data columns (total 23 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   dt           104345 non-null  int64
#  1   switch       104345 non-null  int64
#  2   src          104345 non-null  object
#  3   dst          104345 non-null  object
#  4   pktcount     104345 non-null  int64
#  5   bytecount    104345 non-null  int64
#  6   dur          104345 non-null  int64
#  7   dur_nsec     104345 non-null  int64
#  8   tot_dur      104345 non-null  float64
#  9   flows        104345 non-null  int64
#  10  packetins    104345 non-null  int64
#  11  pktperflow   104345 non-null  int64
#  12  byteperflow  104345 non-null  int64
#  13  pktrate      104345 non-null  int64
#  14  Pairflow     104345 non-null  int64
#  15  Protocol     104345 non-null  object
#  16  port_no      104345 non-null  int64
#  17  tx_bytes     104345 non-null  int64
# ...

# %%
df['tot_kbps'].isna().sum()
# Out:
# 506

# %%
df.loc[df['tot_kbps'].isna()]
# Out:
#          dt  switch        src       dst  pktcount  bytecount  dur   dur_nsec  \
# 19320  2859       1   10.0.0.4  10.0.0.3     91595   95441990  327  484000000
# 19342  2859       1   10.0.0.2  10.0.0.3     48460   51658360  125  674000000
# 19390  2949       1   10.0.0.4  10.0.0.3    116271  121154382  417  495000000
# 19404  3369       1   10.0.0.2  10.0.0.5     97838  104295308  217  144000000
# 19425  2608       1   10.0.0.1  10.0.0.3     75166   80126956  167   17000000
# ...     ...     ...        ...       ...       ...        ...  ...        ...
# 33425  3339       8   10.0.0.3  10.0.0.5     42940   44743480  137  462000000
# 33481  3159       8  10.0.0.12  10.0.0.5     48292   51479272  107  327000000
# 33488  3249       8  10.0.0.12  10.0.0.5     88782   94641612  197  336000000
# 33494  3609       8   10.0.0.3  10.0.0.5    119500  124519000  407  592000000
# 33535  3249       8   10.0.0.3  10.0.0.5     14973   15601866   47  453000000
#
# ...

# %%
df.isna().sum()
# Out:
# dt               0
# switch           0
# src              0
# dst              0
# pktcount         0
# bytecount        0
# dur              0
# dur_nsec         0
# tot_dur          0
# flows            0
# packetins        0
# pktperflow       0
# byteperflow      0
# pktrate          0
# Pairflow         0
# Protocol         0
# port_no          0
# tx_bytes         0
# rx_bytes         0
# tx_kbps          0
# rx_kbps        506
# tot_kbps       506
# label            0
# dtype: int64

# %%
df
# Out:
#            dt  switch        src       dst  pktcount  bytecount  dur  \
# 0       11425       1   10.0.0.1  10.0.0.8     45304   48294064  100
# 1       11605       1   10.0.0.1  10.0.0.8    126395  134737070  280
# 2       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# 3       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# 4       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# ...       ...     ...        ...       ...       ...        ...  ...
# 104340   5262       3   10.0.0.5  10.0.0.7        79       7742   81
# 104341   5262       3   10.0.0.5  10.0.0.7        79       7742   81
# 104342   5262       3  10.0.0.11  10.0.0.5        31       3038   31
# 104343   5262       3  10.0.0.11  10.0.0.5        31       3038   31
# 104344   5262       3  10.0.0.11  10.0.0.5        31       3038   31
#
#          dur_nsec       tot_dur  flows  ...  pktrate  Pairflow  Protocol  \
# ...

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# dt             0
# switch         0
# src            0
# dst            0
# pktcount       0
# bytecount      0
# dur            0
# dur_nsec       0
# tot_dur        0
# flows          0
# packetins      0
# pktperflow     0
# byteperflow    0
# pktrate        0
# Pairflow       0
# Protocol       0
# port_no        0
# tx_bytes       0
# rx_bytes       0
# tx_kbps        0
# rx_kbps        0
# tot_kbps       0
# label          0
# dtype: int64

# %%
df['src'].value_counts()
# Out:
# 10.0.0.3     11395
# 10.0.0.7     10291
# 10.0.0.10     9593
# 10.0.0.1      8627
# 10.0.0.12     8081
# 10.0.0.2      8010
# 10.0.0.5      7291
# 10.0.0.9      7165
# 10.0.0.11     6383
# 10.0.0.4      5973
# 10.0.0.8      5210
# 10.0.0.6      2740
# 10.0.0.18     2590
# 10.0.0.13     2484
# 10.0.0.14     2265
# 10.0.0.15     1858
# 10.0.0.16     1789
# 10.0.0.20     1114
# 10.0.0.17      980
# Name: src, dtype: int64

# %%
df['dst'].value_counts()
# Out:
# 10.0.0.7     18020
# 10.0.0.8     15587
# 10.0.0.5     14876
# 10.0.0.3     12855
# 10.0.0.9      6318
# 10.0.0.12     5635
# 10.0.0.2      4990
# 10.0.0.1      4645
# 10.0.0.4      3963
# 10.0.0.10     3924
# 10.0.0.11     3370
# 10.0.0.14     2007
# 10.0.0.15     1765
# 10.0.0.16     1684
# 10.0.0.6      1590
# 10.0.0.13     1076
# 10.0.0.18      790
# 10.0.0.17      744
# Name: dst, dtype: int64

# %%
df['Protocol'].value_counts()
# Out:
# ICMP    41321
# UDP     33082
# TCP     29436
# Name: Protocol, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
encoder.fit(df['src'])
# Out:
# LabelEncoder()

# %%
df['src'] = encoder.transform(df['src'])

# %%
df['dst'] = encoder.transform(df['dst'])

# %%
df
# Out:
#            dt  switch  src  dst  pktcount  bytecount  dur   dur_nsec  \
# 0       11425       1    0   17     45304   48294064  100  716000000
# 1       11605       1    0   17    126395  134737070  280  734000000
# 2       11425       1   10   17     90333   96294978  200  744000000
# 3       11425       1   10   17     90333   96294978  200  744000000
# 4       11425       1   10   17     90333   96294978  200  744000000
# ...       ...     ...  ...  ...       ...        ...  ...        ...
# 104340   5262       3   14   16        79       7742   81  842000000
# 104341   5262       3   14   16        79       7742   81  842000000
# 104342   5262       3    2   14        31       3038   31  805000000
# 104343   5262       3    2   14        31       3038   31  805000000
# 104344   5262       3    2   14        31       3038   31  805000000
#
#              tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no  \
# ...

# %%
encoder_protocol = LabelEncoder()

# %%
df['Protocol'] = encoder_protocol.fit_transform(df['Protocol'])

# %%
df
# Out:
#            dt  switch  src  dst  pktcount  bytecount  dur   dur_nsec  \
# 0       11425       1    0   17     45304   48294064  100  716000000
# 1       11605       1    0   17    126395  134737070  280  734000000
# 2       11425       1   10   17     90333   96294978  200  744000000
# 3       11425       1   10   17     90333   96294978  200  744000000
# 4       11425       1   10   17     90333   96294978  200  744000000
# ...       ...     ...  ...  ...       ...        ...  ...        ...
# 104340   5262       3   14   16        79       7742   81  842000000
# 104341   5262       3   14   16        79       7742   81  842000000
# 104342   5262       3    2   14        31       3038   31  805000000
# 104343   5262       3    2   14        31       3038   31  805000000
# 104344   5262       3    2   14        31       3038   31  805000000
#
#              tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no  \
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(20,12))
matrix_corr = df.corr()
sns.heatmap(matrix_corr, annot=True, annot_kws={"size" : 7}, linewidths=4)
# Out:
#                    dt    switch       src       dst  pktcount  bytecount  \
# dt           1.000000 -0.006373  0.052876 -0.311550 -0.174345  -0.289111
# switch      -0.006373  1.000000 -0.015079 -0.163674 -0.057639  -0.168475
# src          0.052876 -0.015079  1.000000 -0.204875 -0.158187  -0.170635
# dst         -0.311550 -0.163674 -0.204875  1.000000  0.027435   0.207645
# pktcount    -0.174345 -0.057639 -0.158187  0.027435  1.000000   0.675792
# bytecount   -0.289111 -0.168475 -0.170635  0.207645  0.675792   1.000000
# dur          0.271664 -0.023560  0.101700 -0.094685  0.023222   0.038033
# dur_nsec    -0.166514 -0.077123  0.029898  0.136881  0.034283   0.029418
# tot_dur      0.271475 -0.023687  0.101786 -0.094527  0.023283   0.038034
# flows        0.327694 -0.028017  0.150371 -0.162073 -0.257467  -0.244514
# packetins    0.043491  0.199984 -0.010740 -0.256697  0.275867  -0.124840
# pktperflow  -0.233717 -0.036071 -0.148120  0.091733  0.470065   0.333530
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:, :-1]
Y = df.iloc[:, -1]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=30, test_size=0.3)

# %%
classifier.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
classifier.score(X_test, Y_test)
# Out:
# 0.6062853107344632

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier_RF = RandomForestClassifier()

# %%
classifier_RF.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
classifier_RF.score(X_test, Y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix

# %%
Y_pred = classifier_RF.predict(X_test)
Y_pred_1 = classifier_RF.predict(X_train)

# %%
mat = confusion_matrix(Y_pred_1, Y_train)

# %%
sns.heatmap(mat, annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_pred, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     18968
#            1       1.00      1.00      1.00     12184
#
#     accuracy                           1.00     31152
#    macro avg       1.00      1.00      1.00     31152
# weighted avg       1.00      1.00      1.00     31152

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
classifier_KN = KNeighborsClassifier()

# %%
classifier_KN.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
classifier_KN.score(X_test, Y_test)
# Out:
# 0.8854969183359014

# %%
y_pred_KN = classifier_KN.predict(X_test)

# %%
sns.heatmap(confusion_matrix(y_pred_KN, Y_test), annot=True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_pred_KN, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91     19701
#            1       0.82      0.88      0.85     11451
#
#     accuracy                           0.89     31152
#    macro avg       0.87      0.88      0.88     31152
# weighted avg       0.89      0.89      0.89     31152

# %%
SDN_data = df
SDN_data
# Out:
#            dt  switch  src  dst  pktcount  bytecount  dur   dur_nsec  \
# 0       11425       1    0   17     45304   48294064  100  716000000
# 1       11605       1    0   17    126395  134737070  280  734000000
# 2       11425       1   10   17     90333   96294978  200  744000000
# 3       11425       1   10   17     90333   96294978  200  744000000
# 4       11425       1   10   17     90333   96294978  200  744000000
# ...       ...     ...  ...  ...       ...        ...  ...        ...
# 104340   5262       3   14   16        79       7742   81  842000000
# 104341   5262       3   14   16        79       7742   81  842000000
# 104342   5262       3    2   14        31       3038   31  805000000
# 104343   5262       3    2   14        31       3038   31  805000000
# 104344   5262       3    2   14        31       3038   31  805000000
#
#              tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no  \
# ...

# %%
corr_matrix_SDN = SDN_data.corr()
plt.figure(figsize=(20,12))
sns.heatmap(matrix_corr, annot=True, annot_kws={"size" : 7}, linewidths=4)
# Out:
# <AxesSubplot:>

# %%
corr_matrix_SDN
# Out:
#                    dt    switch       src       dst  pktcount  bytecount  \
# dt           1.000000 -0.006373  0.052876 -0.311550 -0.174345  -0.289111
# switch      -0.006373  1.000000 -0.015079 -0.163674 -0.057639  -0.168475
# src          0.052876 -0.015079  1.000000 -0.204875 -0.158187  -0.170635
# dst         -0.311550 -0.163674 -0.204875  1.000000  0.027435   0.207645
# pktcount    -0.174345 -0.057639 -0.158187  0.027435  1.000000   0.675792
# bytecount   -0.289111 -0.168475 -0.170635  0.207645  0.675792   1.000000
# dur          0.271664 -0.023560  0.101700 -0.094685  0.023222   0.038033
# dur_nsec    -0.166514 -0.077123  0.029898  0.136881  0.034283   0.029418
# tot_dur      0.271475 -0.023687  0.101786 -0.094527  0.023283   0.038034
# flows        0.327694 -0.028017  0.150371 -0.162073 -0.257467  -0.244514
# packetins    0.043491  0.199984 -0.010740 -0.256697  0.275867  -0.124840
# pktperflow  -0.233717 -0.036071 -0.148120  0.091733  0.470065   0.333530
# ...

# %%
dropped_features = ['pktperflow', 'dur', 'byteperflow']
SDN_data_features = SDN_data.drop(columns=dropped_features)
X_features = SDN_data_features.iloc[:, :-1]
Y_features = SDN_data_features.iloc[:, -1]

# %%
plt.figure(figsize=(20,12))
sns.heatmap(SDN_data_features.corr(), annot=True, annot_kws={"size" : 7}, linewidths=4)
# Out:
# <AxesSubplot:>

# %%
low_related_features = ['switch','port_no', 'rx_kbps', 'tx_kbps', 'tot_kbps', 'tx_bytes', 'rx_bytes', 'packetins', 'dur_nsec', 'Pairflow']
SDN_data_features = SDN_data_features.drop(columns=low_related_features)

# %%
plt.figure(figsize=(20,12))
sns.heatmap(SDN_data_features.corr(), annot=True, annot_kws={"size" : 7}, linewidths=4)
# Out:
# <AxesSubplot:>

# %%
X_features = SDN_data_features.iloc[:, :-1]
Y_features = SDN_data_features.iloc[:, -1]

# %%
X_train_features, X_test_features, Y_train_features, Y_test_features = train_test_split(X_features, Y_features)

# %%
classifier_RF.fit(X_train_features,Y_train_features)
# Out:
# RandomForestClassifier()

# %%
classifier_RF.score(X_test_features, Y_test_features)
# Out:
# 1.0

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import make_pipeline

# %%
model_params = {
    'Naive_Bayes' : {
      'model' : GaussianNB(),
      'params' : {
          
      }  
    },
    'random_forest' : {
        'model' : RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators' : [100, 110, 120, 150, 200]
        }
    },
    'logistic_regression': {
        'model' : LogisticRegression(),
        'params' : {
            'logisticregression__solver' : [ 'newton-cg', 'sag', 'saga'],
            'logisticregression__C' : [1, 10, 20]
        }
    },
    'KNN' : {
      'model' : KNeighborsClassifier(),
      'params' : { 
          'kneighborsclassifier__n_neighbors' : [3, 4, 5]
      } 
    }
}

# %%
scores = []
best_esmti = {}

for algo, mp in model_params.items():
    pipe = make_pipeline(mp['model'])
    clf = GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train_features, Y_train_features)
    scores.append({
        'model' : algo,
        'best_score' : clf.best_score_,
        'best_params' : clf.best_params_
    })
    best_esmti[algo] = clf.best_estimator_
# Out:
# c:\Users\jonua\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_linesearch.py:456: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# c:\Users\jonua\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_linesearch.py:305: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# c:\Users\jonua\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_linesearch.py:415: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# c:\Users\jonua\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# ...

# %%
df = pd.DataFrame(scores)
df
# Out:
#                  model  best_score  \
# 0          Naive_Bayes    0.634240
# 1        random_forest    0.999936
# 2  logistic_regression    0.653411
# 3                  KNN    0.976528
#
#                                          best_params
# 0                                                 {}
# 1      {'randomforestclassifier__n_estimators': 100}
# 2  {'logisticregression__C': 20, 'logisticregress...
# 3           {'kneighborsclassifier__n_neighbors': 3}

# %%
classifier_df = df.iloc[:, :-1]

# %%
classifier_df
# Out:
#                  model  best_score
# 0          Naive_Bayes    0.634240
# 1        random_forest    0.999936
# 2  logistic_regression    0.653411
# 3                  KNN    0.976528

# %%
classifier_df.columns = ['Alogrithm', 'Accuracy']
classifier_df = classifier_df.sort_values(by='Accuracy', ascending=False)

# %%
print("PARAMETER OPTIMISED ALGORITHM MODELS:")
classifier_df.reset_index(drop='index')
# Out:
# PARAMETER OPTIMISED ALGORITHM MODELS:
#              Alogrithm  Accuracy
# 0        random_forest  0.999936
# 1                  KNN  0.976528
# 2  logistic_regression  0.653411
# 3          Naive_Bayes  0.634240

# %%
print("FEATURES CONSIDERED :")
for i in X_train_features:
    print(i)
# Out:
# FEATURES CONSIDERED :
# dt
# src
# dst
# pktcount
# bytecount
# tot_dur
# flows
# pktrate
# Protocol

# %%
classifier_df.iloc[0]
# Out:
# Alogrithm    random_forest
# Accuracy          0.999936
# Name: 1, dtype: object

# %%
matrices = []

for i in best_esmti:
    y_temp_pred = best_esmti[i].predict(X_test_features)
    matrices.append(confusion_matrix(Y_test_features, y_temp_pred))
    print(i+"\n",classification_report(Y_test_features, y_temp_pred))
# Out:
# Naive_Bayes
#                precision    recall  f1-score   support
#
#            0       0.66      0.82      0.74     15898
#            1       0.55      0.34      0.42     10062
#
#     accuracy                           0.64     25960
#    macro avg       0.61      0.58      0.58     25960
# weighted avg       0.62      0.64      0.61     25960
#
# random_forest
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15898
#            1       1.00      1.00      1.00     10062
#
#     accuracy                           1.00     25960
#    macro avg       1.00      1.00      1.00     25960
# weighted avg       1.00      1.00      1.00     25960
#
# logistic_regression
#                precision    recall  f1-score   support
#
#            0       0.72      0.75      0.74     15898
#            1       0.58      0.54      0.56     10062
#
#     accuracy                           0.67     25960
# ...
